# %% [markdown]
# <a href="https://colab.research.google.com/github/Agnes-FD/Agnes-FD/blob/main/model_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Memasukkan data dari google drive

from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/data'
# Out:
# /content/drive/MyDrive/data

# %%
ls
# Out:
# with_mask/  without_mask/

# %%
import os
path = '/content/drive/MyDrive/data'
# Membuat Label pada gambar berdasarkan klasifikasi
file_name = []
tag = []
full_path = []
for path, subdirs, files in os.walk(path):
  for name in files:
    full_path.append(os.path.join(path, name))
    tag.append(path.split('/')[-1])
    file_name.append(name)

# %%
print(tag)

# %%
# Membuat dataframe berdasarkan hasil klasifikasi data yang sudah diberi label
import pandas as pd

df = pd.DataFrame({"path":full_path, "file_name": file_name, "tag":tag})
df.groupby(['tag']).size()
# Out:
# tag
# with_mask       3725
# without_mask    3828
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7553 entries, 0 to 7552
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   path       7553 non-null   object
#  1   file_name  7553 non-null   object
#  2   tag        7553 non-null   object
# dtypes: object(3)
# memory usage: 177.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(df.tag)
plt.xlabel('Category')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Category')

# %%
# cek data yang sudah diberi label
df
# Out:
#                                                    path  ...           tag
# 0     /content/drive/MyDrive/data/with_mask/with_mas...  ...     with_mask
# 1     /content/drive/MyDrive/data/with_mask/with_mas...  ...     with_mask
# 2     /content/drive/MyDrive/data/with_mask/with_mas...  ...     with_mask
# 3     /content/drive/MyDrive/data/with_mask/with_mas...  ...     with_mask
# 4     /content/drive/MyDrive/data/with_mask/with_mas...  ...     with_mask
# ...                                                 ...  ...           ...
# 7548  /content/drive/MyDrive/data/without_mask/witho...  ...  without_mask
# 7549  /content/drive/MyDrive/data/without_mask/witho...  ...  without_mask
# 7550  /content/drive/MyDrive/data/without_mask/witho...  ...  without_mask
# 7551  /content/drive/MyDrive/data/without_mask/witho...  ...  without_mask
# 7552  /content/drive/MyDrive/data/without_mask/witho...  ...  without_mask
#
# [7553 rows x 3 columns]

# %%
# Membagi dataset menjadi dua bagian (train dan test)
from sklearn.model_selection import train_test_split

x = df['path']
y = df['tag']

x_train, x_test, y_train, y_test = train_test_split(
    x,y, test_size= 0.2, random_state=1
)

# %%
# menyatukan kedalam masing-masing dataframe
df_test = pd.DataFrame({
    'path' : x_test,
    'tag' : y_test,
    'set' : 'test-set'
})

df_train = pd.DataFrame({
    'path' : x_train,
    'tag' : y_train,
    'set' : 'train-set'
})

# %%
print('train size', len(df_train))
print('test size', len(df_test))
# Out:
# train size 6042
# test size 1511

# %%
# melihat masing-masing dataset apakah sudah sesuai atau belum
df_all = df_train.append([df_test]).reset_index(drop=1)

print('===================================================== \n')
print(df_all.groupby(['set','tag']).size(),'\n')

print('===================================================== \n')

df_all.sample(4)
# Out:
# =====================================================
#
# set        tag
# test-set   with_mask        741
#            without_mask     770
# train-set  with_mask       2984
#            without_mask    3058
# dtype: int64
#
# =====================================================
#                                                    path  ...        set
# 13    /content/drive/MyDrive/data/with_mask/with_mas...  ...  train-set
# 776   /content/drive/MyDrive/data/with_mask/with_mas...  ...  train-set
# 5246  /content/drive/MyDrive/data/without_mask/witho...  ...  train-set
# 5580  /content/drive/MyDrive/data/with_mask/with_mas...  ...  train-set
#
# [4 rows x 3 columns]

# %%
# Memindahkan dataset
import shutil
from tqdm.notebook import tqdm as tq

# %%
datasource_path = '/content/drive/MyDrive/data'
dataset_path = '/content/drive/MyDrive/dataset'

# %%
for index, row in tq(df_all.iterrows()):
  file_path = row['path']

  if os.path.exists(file_path) == False:
    file_path = os.path.join(datasource_path, row['tag'], row['image'].split('.')[0])

  if os.path.exists(os.path.join(dataset_path, row['set'], row['tag'])) == False:
    os.makedirs(os.path.join(dataset_path, row['set'], row['tag']))
  
  destination_file_name = file_path.split('/')[-1]
  file_dest = os.path.join(dataset_path, row['set'], row['tag'], destination_file_name)

  if os.path.exists(file_dest) == False:
    shutil.copy2(file_path, file_dest)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
# Define Directory
base_dir = '/content/drive/MyDrive/dataset'
train_dir = os.path.join(base_dir, 'train-set')
test_dir = os.path.join(base_dir, 'test-set')

# %%
os.listdir(train_dir)
# Out:
# ['without_mask', 'with_mask']

# %%
os.listdir(test_dir)
# Out:
# ['with_mask', 'without_mask']

# %%
train_without_mask_dir = os.path.join(train_dir, 'without_mask')
train_with_mask_dir = os.path.join(train_dir, 'with_mask')
test_without_mask_dir = os.path.join(test_dir, 'without_mask')
test_with_mask_dir = os.path.join(test_dir, 'with_mask')

# %%
# Image Augmentation
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(tf.__version__)
# Out:
# 2.4.1

# %%
datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 90,
    horizontal_flip=True,
    fill_mode='nearest'
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size = (224, 224),
    batch_size = 16,
    class_mode = 'binary'
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size = (224, 224),
    batch_size = 16,
    class_mode = 'binary'
)
# Out:
# Found 6042 images belonging to 2 classes.
# Found 1511 images belonging to 2 classes.

# %%
# Membuat Model CNN menggunakan Transfer Learning MobileNetV2
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Input

# %%
model_cnn = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(224,224,3)),
    tf.keras.layers.MaxPooling2D(3,3),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(3,3),
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 72, 72, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30976)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,344,193
# Trainable params: 4,344,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.97):
      print('Akurasi mencapai 97%, proses training dihentikan!')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model_cnn.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

history_cnn = model_cnn.fit(
    train_generator,
    steps_per_epoch = 20,
    epochs = 50,
    validation_data = test_generator,
    validation_steps = 3,
    callbacks = [callbacks]
)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 218s 11s/step - loss: 0.8266 - accuracy: 0.4555 - val_loss: 0.6938 - val_accuracy: 0.4583
# Epoch 2/50
# 20/20 [==============================] - 209s 11s/step - loss: 0.6905 - accuracy: 0.5404 - val_loss: 0.7029 - val_accuracy: 0.4167
# Epoch 3/50
# 20/20 [==============================] - 203s 10s/step - loss: 0.6940 - accuracy: 0.5475 - val_loss: 0.6980 - val_accuracy: 0.5000
# Epoch 4/50
#  2/20 [==>...........................] - ETA: 2:29 - loss: 0.7081 - accuracy: 0.4688
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 20/20 [==============================] - 187s 9s/step - loss: 0.6492 - accuracy: 0.6025 - val_loss: 0.5081 - val_accuracy: 0.7917
# Epoch 5/50
# 20/20 [==============================] - 174s 9s/step - loss: 0.5540 - accuracy: 0.7243 - val_loss: 0.3719 - val_accuracy: 0.8333
# Epoch 6/50
# 20/20 [==============================] - 166s 8s/step - loss: 0.6202 - accuracy: 0.6493 - val_loss: 0.5506 - val_accuracy: 0.7083
# Epoch 7/50
# 20/20 [==============================] - 154s 8s/step - loss: 0.5440 - accuracy: 0.7456 - val_loss: 0.4173 - val_accuracy: 0.8542
# Epoch 8/50
# 20/20 [==============================] - 149s 8s/step - loss: 0.5383 - accuracy: 0.7808 - val_loss: 0.3893 - val_accuracy: 0.7917
# Epoch 9/50
# 20/20 [==============================] - 145s 7s/step - loss: 0.4056 - accuracy: 0.8115 - val_loss: 0.2022 - val_accuracy: 0.9375
# Epoch 10/50
# 20/20 [==============================] - 133s 7s/step - loss: 0.3613 - accuracy: 0.8549 - val_loss: 0.3776 - val_accuracy: 0.8333
# Epoch 11/50
# 20/20 [==============================] - 133s 7s/step - loss: 0.3965 - accuracy: 0.8443 - val_loss: 0.3443 - val_accuracy: 0.8750
# Epoch 12/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.3934 - accuracy: 0.8289 - val_loss: 0.4203 - val_accuracy: 0.7917
# Epoch 13/50
# 20/20 [==============================] - 109s 5s/step - loss: 0.3699 - accuracy: 0.8768 - val_loss: 0.3106 - val_accuracy: 0.8542
# Epoch 14/50
# 20/20 [==============================] - 111s 6s/step - loss: 0.2657 - accuracy: 0.8975 - val_loss: 0.3279 - val_accuracy: 0.8750
# Epoch 15/50
# 20/20 [==============================] - 99s 5s/step - loss: 0.2366 - accuracy: 0.9087 - val_loss: 0.3987 - val_accuracy: 0.8125
# Epoch 16/50
# 20/20 [==============================] - 99s 5s/step - loss: 0.5036 - accuracy: 0.7806 - val_loss: 0.4608 - val_accuracy: 0.7917
# Epoch 17/50
# 20/20 [==============================] - 100s 5s/step - loss: 0.3581 - accuracy: 0.8412 - val_loss: 0.3709 - val_accuracy: 0.8333
# Epoch 18/50
# 20/20 [==============================] - 93s 5s/step - loss: 0.3750 - accuracy: 0.8721 - val_loss: 0.3106 - val_accuracy: 0.9375
# Epoch 19/50
# 20/20 [==============================] - 93s 5s/step - loss: 0.4884 - accuracy: 0.8046 - val_loss: 0.3689 - val_accuracy: 0.8333
# Epoch 20/50
# 20/20 [==============================] - 89s 4s/step - loss: 0.3921 - accuracy: 0.8425 - val_loss: 0.2843 - val_accuracy: 0.8750
# Epoch 21/50
# 20/20 [==============================] - 81s 4s/step - loss: 0.4317 - accuracy: 0.8513 - val_loss: 0.3393 - val_accuracy: 0.8542
# Epoch 22/50
# 20/20 [==============================] - 77s 4s/step - loss: 0.4236 - accuracy: 0.8415 - val_loss: 0.4666 - val_accuracy: 0.8333
# Epoch 23/50
# 20/20 [==============================] - 73s 4s/step - loss: 0.3845 - accuracy: 0.8335 - val_loss: 0.2903 - val_accuracy: 0.9167
# Epoch 24/50
# 20/20 [==============================] - 67s 3s/step - loss: 0.4087 - accuracy: 0.8284 - val_loss: 0.3103 - val_accuracy: 0.8750
# Epoch 25/50
# 20/20 [==============================] - 64s 3s/step - loss: 0.2880 - accuracy: 0.9074 - val_loss: 0.3082 - val_accuracy: 0.8958
# Epoch 26/50
# 20/20 [==============================] - 65s 3s/step - loss: 0.3639 - accuracy: 0.8269 - val_loss: 0.3672 - val_accuracy: 0.8125
# Epoch 27/50
# 20/20 [==============================] - 61s 3s/step - loss: 0.3685 - accuracy: 0.8515 - val_loss: 0.4891 - val_accuracy: 0.8125
# Epoch 28/50
# 20/20 [==============================] - 63s 3s/step - loss: 0.3581 - accuracy: 0.8738 - val_loss: 0.3040 - val_accuracy: 0.9167
# Epoch 29/50
# 20/20 [==============================] - 61s 3s/step - loss: 0.4414 - accuracy: 0.8219 - val_loss: 0.3166 - val_accuracy: 0.8125
# Epoch 30/50
# 20/20 [==============================] - 63s 3s/step - loss: 0.3069 - accuracy: 0.8800 - val_loss: 0.2763 - val_accuracy: 0.9167
# Epoch 31/50
# 20/20 [==============================] - 52s 3s/step - loss: 0.3497 - accuracy: 0.8080 - val_loss: 0.2445 - val_accuracy: 0.8958
# Epoch 32/50
# 20/20 [==============================] - 56s 3s/step - loss: 0.4602 - accuracy: 0.8231 - val_loss: 0.2129 - val_accuracy: 0.9375
# Epoch 33/50
# 20/20 [==============================] - 52s 3s/step - loss: 0.3570 - accuracy: 0.8498 - val_loss: 0.3041 - val_accuracy: 0.8750
# Epoch 34/50
# 20/20 [==============================] - 55s 3s/step - loss: 0.3557 - accuracy: 0.8253 - val_loss: 0.5384 - val_accuracy: 0.8125
# Epoch 35/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.3282 - accuracy: 0.8918 - val_loss: 0.2046 - val_accuracy: 0.9167
# Epoch 36/50
# 20/20 [==============================] - 55s 3s/step - loss: 0.3416 - accuracy: 0.8705 - val_loss: 0.2361 - val_accuracy: 0.8750
# Epoch 37/50
# 20/20 [==============================] - 53s 3s/step - loss: 0.3269 - accuracy: 0.8756 - val_loss: 0.2679 - val_accuracy: 0.8750
# Epoch 38/50
# 20/20 [==============================] - 46s 2s/step - loss: 0.4039 - accuracy: 0.8732 - val_loss: 0.3074 - val_accuracy: 0.9167
# Epoch 39/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.3327 - accuracy: 0.8854 - val_loss: 0.2428 - val_accuracy: 0.8958
# Epoch 40/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.3646 - accuracy: 0.8442 - val_loss: 0.3840 - val_accuracy: 0.7917
# Epoch 41/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.4624 - accuracy: 0.8090 - val_loss: 0.2454 - val_accuracy: 0.9167
# Epoch 42/50
# 20/20 [==============================] - 47s 2s/step - loss: 0.2953 - accuracy: 0.8806 - val_loss: 0.3557 - val_accuracy: 0.8333
# Epoch 43/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.5040 - accuracy: 0.8457 - val_loss: 0.2931 - val_accuracy: 0.8750
# Epoch 44/50
# 20/20 [==============================] - 51s 2s/step - loss: 0.2766 - accuracy: 0.8915 - val_loss: 0.2419 - val_accuracy: 0.9375
# Epoch 45/50
# 20/20 [==============================] - 44s 2s/step - loss: 0.4656 - accuracy: 0.8173 - val_loss: 0.3957 - val_accuracy: 0.8333
# Epoch 46/50
# 20/20 [==============================] - 41s 2s/step - loss: 0.3596 - accuracy: 0.8546 - val_loss: 0.2950 - val_accuracy: 0.8750
# Epoch 47/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.3415 - accuracy: 0.8702 - val_loss: 0.2581 - val_accuracy: 0.9375
# Epoch 48/50
# 20/20 [==============================] - 45s 2s/step - loss: 0.3343 - accuracy: 0.8698 - val_loss: 0.4531 - val_accuracy: 0.7917
# Epoch 49/50
# 20/20 [==============================] - 43s 2s/step - loss: 0.3515 - accuracy: 0.8362 - val_loss: 0.3268 - val_accuracy: 0.8333
# Epoch 50/50
# 20/20 [==============================] - 42s 2s/step - loss: 0.3041 - accuracy: 0.9014 - val_loss: 0.2743 - val_accuracy: 0.9375

# %%
acc = history_cnn.history['accuracy']
val_acc = history_cnn.history['val_accuracy']
loss = history_cnn.history['loss']
val_loss = history_cnn.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'blue', label='Training accuracy')
plt.plot(epochs, val_acc, 'orange', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'blue', label='Training Loss')
plt.plot(epochs, val_loss, 'orange', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(224,224))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 224, 224, 3)
  prediksi = model_cnn.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-9dbb04b6-94c0-4d11-a797-f4902331b707" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dbb04b6-94c0-4d11-a797-f4902331b707">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index.jpg to index.jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(224,224))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 224, 224, 3)
  prediksi = model_cnn.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-885d17c0-52cb-440f-8eff-6779c3dd090a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-885d17c0-52cb-440f-8eff-6779c3dd090a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mega.jpg to mega.jpg
# Not Wearing Masker

# %%
model_cnn.save("/content/drive/MyDrive/Model_TA")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Model_TA/assets
