# %% [markdown]
# <a href="https://colab.research.google.com/github/Agnes-FD/Agnes-FD/blob/main/TEST_Wiwit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import requests
from io import BytesIO

from PIL import Image
import numpy as np

# %%
# Parameters
input_size = (256,256,3)

#define input shape
channel = (3,)
input_shape = input_size + channel

#define labels
labels = ['with_mask', 'without_mask']

# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size, resample= 0)
    img_arr = (np.array(nimg))/255
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
from tensorflow.keras.models import load_model

# %%
#load model
MODEL_PATH = '/content/drive/MyDrive/Colab Notebooks/Model/CNN/Model_CNN20.h5'
model = load_model(MODEL_PATH,compile=False)

# %%
cd ('/content/drive/MyDrive/GAMBAR')
# Out:
# [Errno 2] No such file or directory: '(/content/drive/MyDrive/GAMBAR)'
# /content

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-fc7add3d-d30f-4805-874c-fd76b749f724" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc7add3d-d30f-4805-874c-fd76b749f724">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitmask1.jpeg to wiwitmask1.jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-9e033554-47b2-4fb9-9fa8-ac3a6178d844" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e033554-47b2-4fb9-9fa8-ac3a6178d844">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitmask2.jpeg to wiwitmask2.jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-631249db-8792-4eeb-b143-b7e62304697d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-631249db-8792-4eeb-b143-b7e62304697d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitmask3.jpeg to wiwitmask3.jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-2a041e66-18c6-407f-8d17-55667d0b8436" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a041e66-18c6-407f-8d17-55667d0b8436">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitmask4.jpeg to wiwitmask4.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-0b65edae-18f0-4652-a357-d4f2e5186c50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b65edae-18f0-4652-a357-d4f2e5186c50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitmask5.jpeg to wiwitmask5.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-919af84d-8426-468e-a82e-d7c6ac3873bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-919af84d-8426-468e-a82e-d7c6ac3873bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitnomask1.jpeg to wiwitnomask1.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-5238ed29-d5cd-47a3-bc31-b7f3a1f7ed72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5238ed29-d5cd-47a3-bc31-b7f3a1f7ed72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitnomask2.jpeg to wiwitnomask2.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-fdbfa537-6a02-468c-8e1b-6564d8ef0286" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdbfa537-6a02-468c-8e1b-6564d8ef0286">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitnomask3.jpeg to wiwitnomask3.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-544cc65f-202f-47d8-8261-7d6c82194734" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-544cc65f-202f-47d8-8261-7d6c82194734">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitnomask4.jpeg to wiwitnomask4.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-a25b1102-a32d-4b1c-b198-7ac446ef9dbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a25b1102-a32d-4b1c-b198-7ac446ef9dbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiwitnomask5.jpeg to wiwitnomask5.jpeg
# Not Wearing Masker
