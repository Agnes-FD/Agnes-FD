# %% [markdown]
# <a href="https://colab.research.google.com/github/Agnes-FD/Agnes-FD/blob/main/Test11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g6oOourtS25IcruJh9irx6VXVfrnSQIOX0SRGiQBms41Qo_WlPT6YU
# Mounted at /content/drive

# %%
import requests
from io import BytesIO

from PIL import Image
import numpy as np

# %%
# Parameters
input_size = (256,256,3)

#define input shape
channel = (3,)
input_shape = input_size + channel

#define labels
labels = ['with_mask', 'without_mask']

# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size, resample= 0)
    img_arr = (np.array(nimg))/255
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
from tensorflow.keras.models import load_model

# %%
#load model
MODEL_PATH = '/content/drive/MyDrive/Colab Notebooks/Model/CNN/Model_CNN18.h5'
model = load_model(MODEL_PATH,compile=False)

# %%
cd ('/content/drive/MyDrive/GAMBAR')
# Out:
# [Errno 2] No such file or directory: '(/content/drive/MyDrive/GAMBAR)'
# /content

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-7a92f083-ad4b-45b8-8ea0-0e8a09d96bd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a92f083-ad4b-45b8-8ea0-0e8a09d96bd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index........jpg to index........jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-2775731c-010f-40e8-b848-6cd34df41f04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2775731c-010f-40e8-b848-6cd34df41f04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index2.........jpg to index2.........jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-1f6cfbf5-87ca-4b22-9937-9af26c87fc09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f6cfbf5-87ca-4b22-9937-9af26c87fc09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index3.........jpg to index3.........jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-656a1379-0d60-4349-a4b2-85b5e7390eb6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-656a1379-0d60-4349-a4b2-85b5e7390eb6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index4........jpg to index4........jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-8595bd8c-2c36-46c2-ac4a-88645b62778d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8595bd8c-2c36-46c2-ac4a-88645b62778d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1....jpeg to 1....jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-fdee1258-8010-4a26-9d70-050caa15c4ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdee1258-8010-4a26-9d70-050caa15c4ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2....jpeg to 2....jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-574ba8f7-4c69-4b6d-affe-1e00d40b47b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-574ba8f7-4c69-4b6d-affe-1e00d40b47b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3....jpeg to 3....jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-5bca9480-f6ba-4f2a-bed8-df38f8a3c789" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bca9480-f6ba-4f2a-bed8-df38f8a3c789">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4...jpeg to 4...jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-392def8d-5d43-435f-ac96-2c760674302f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-392def8d-5d43-435f-ac96-2c760674302f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5...jpeg to 5...jpeg
# Wearing Masker
