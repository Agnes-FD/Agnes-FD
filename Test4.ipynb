# %% [markdown]
# <a href="https://colab.research.google.com/github/Agnes-FD/Agnes-FD/blob/main/Test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g6oOourtS25IcruJh9irx6VXVfrnSQIOX0SRGiQBms41Qo_WlPT6YU
# Mounted at /content/drive

# %%
import requests
from io import BytesIO

from PIL import Image
import numpy as np

# %%
# Parameters
input_size = (256,256,3)

#define input shape
channel = (3,)
input_shape = input_size + channel

#define labels
labels = ['with_mask', 'without_mask']

# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size, resample= 0)
    img_arr = (np.array(nimg))/255
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
from tensorflow.keras.models import load_model

# %%
#load model
MODEL_PATH = '/content/drive/MyDrive/Colab Notebooks/Model/CNN/Model_CNN18.h5'
model = load_model(MODEL_PATH,compile=False)

# %%
cd ('/content/drive/MyDrive/GAMBAR')
# Out:
# [Errno 2] No such file or directory: '(/content/drive/MyDrive/GAMBAR)'
# /content

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-e67f2c88-c7e2-42f7-891b-b83c8e66583d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e67f2c88-c7e2-42f7-891b-b83c8e66583d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving (1).jpg to (1).jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-6bfbce87-0b64-444a-9e43-bb4d0a6e91bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bfbce87-0b64-444a-9e43-bb4d0a6e91bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index2.jpg to index2 (2).jpg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-c928d52d-babd-4c20-b6cd-176dbfcf2944" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c928d52d-babd-4c20-b6cd-176dbfcf2944">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index3.jpg to index3.jpg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-478bf4db-0d61-468b-9fe3-9dbdb9f5574e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-478bf4db-0d61-468b-9fe3-9dbdb9f5574e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index4.jpg to index4.jpg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-5eafc8c4-d4d3-4e40-b864-d9b64909469f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5eafc8c4-d4d3-4e40-b864-d9b64909469f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving index5.jpg to index5 (1).jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-fbea1f9d-51a5-42d8-a217-32670781e6ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbea1f9d-51a5-42d8-a217-32670781e6ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-04-20 at 11.54.37.jpeg to WhatsApp Image 2021-04-20 at 11.54.37.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-a8313ee5-ab36-4c22-b90e-755de9d126ad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8313ee5-ab36-4c22-b90e-755de9d126ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-04-20 at 11.56.17 (1).jpeg to WhatsApp Image 2021-04-20 at 11.56.17 (1).jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-30d05741-d49c-45a9-afed-40a7cd1b89d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30d05741-d49c-45a9-afed-40a7cd1b89d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-04-20 at 11.56.17 (2).jpeg to WhatsApp Image 2021-04-20 at 11.56.17 (2).jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-9f3bd08c-6be2-49b5-9a73-27378ad2e40a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f3bd08c-6be2-49b5-9a73-27378ad2e40a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-04-20 at 11.56.17.jpeg to WhatsApp Image 2021-04-20 at 11.56.17.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(256,256))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 256, 256, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-17e822a9-b561-4dab-84c8-1f026c230a6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17e822a9-b561-4dab-84c8-1f026c230a6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Image 2021-04-20 at 11.57.16 (1).jpeg to WhatsApp Image 2021-04-20 at 11.57.16 (1).jpeg
# Not Wearing Masker
