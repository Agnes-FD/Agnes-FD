# %% [markdown]
# <a href="https://colab.research.google.com/github/Agnes-FD/Agnes-FD/blob/main/Test3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
from io import BytesIO

from PIL import Image
import numpy as np

# %%
# Parameters
input_size = (128,128,3)

#define input shape
channel = (3,)
input_shape = input_size + channel

#define labels
labels = ['with_mask', 'without_mask']

# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size, resample= 0)
    img_arr = (np.array(nimg))/255
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
from tensorflow.keras.models import load_model

# %%
#load model
MODEL_PATH = '/content/drive/MyDrive/Colab Notebooks/Model/CNN/Model_CNN21.h5'
model = load_model(MODEL_PATH,compile=False)

# %%
cd ('/content/drive/MyDrive/GAMBAR')
# Out:
# [Errno 2] No such file or directory: '(/content/drive/MyDrive/GAMBAR)'
# /content

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-a079c35f-c2ee-4bbc-b5c6-42dfe9a63395" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a079c35f-c2ee-4bbc-b5c6-42dfe9a63395">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesmask1.jpeg to agnesmask1.jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-d549b49c-0c37-4208-972f-04b82ec89b04" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d549b49c-0c37-4208-972f-04b82ec89b04">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesmask2.jpeg to agnesmask2 (1).jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-07f3d407-3921-411e-925d-26792b065552" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07f3d407-3921-411e-925d-26792b065552">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesmask3.jpeg to agnesmask3.jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-1af2a391-409c-4683-81c1-bd2488813176" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1af2a391-409c-4683-81c1-bd2488813176">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesmask4.jpg to agnesmask4.jpg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-8ec6c6f4-a2ee-4e27-b14c-d4be2c65bbb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ec6c6f4-a2ee-4e27-b14c-d4be2c65bbb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agneswithmask5.jpeg to agneswithmask5.jpeg
# Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-0567f357-517c-4357-b47b-8f7f536de360" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0567f357-517c-4357-b47b-8f7f536de360">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesnomask1.jpeg to agnesnomask1 (1).jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-3bfcb4cf-4735-4952-b8ba-56e17348052d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bfcb4cf-4735-4952-b8ba-56e17348052d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesnomask2.jpeg to agnesnomask2.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-f3f51954-b19b-4f5c-abb5-43ed99b34745" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3f51954-b19b-4f5c-abb5-43ed99b34745">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesnomask3.jpeg to agnesnomask3.jpeg
# Not Wearing Masker

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  path = fn
  img = image.load_img(path,target_size=(128,128))
  plt.imshow(img)
  plt.axis('off')
  plt.show()

  img = np.array(img, dtype='float')
  img = img.reshape(1, 128, 128, 3)
  prediksi = model.predict(img)
  idx = prediksi[0][0]
  if (idx):
      print("Not Wearing Masker")
  else:
      print("Wearing Masker")
# Out:
#      <input type="file" id="files-f1078917-e730-44d6-9c75-0841d10d15f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1078917-e730-44d6-9c75-0841d10d15f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving agnesnomask4.jpeg to agnesnomask4.jpeg
# Not Wearing Masker
